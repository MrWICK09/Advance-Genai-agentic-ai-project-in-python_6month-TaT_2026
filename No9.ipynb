# %%
nit = 1030

# %%
nit
# Out:
# 1030

# %%
1030 = a
# Out:
#   Cell In[3], line 1
#     1030 = a
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
1nit=10
1nit
# Out:
#   Cell In[5], line 1
#     1nit=10
#     ^
# SyntaxError: invalid decimal literal

# %%
nit1=10
nit1
# Out:
# 10

# %%
nit=10
NIT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 nit=10
# ----> 2 NIT
#
# NameError: name 'NIT' is not defined

# %%
nit@=10
nit@
# Out:
#   Cell In[8], line 2
#     nit@
#         ^
# SyntaxError: invalid syntax

# %%
nit_ =10
nit_
# Out:
# 10

# %%
_=10
_
# Out:
# 10

# %%
_a=10
_a
# Out:
# 10

# %%
#variable(object)=value(datatypes)

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
#for as it is the part of the loop
for=10
for
# Out:
#   Cell In[17], line 2
#     for=10
#        ^
# SyntaxError: invalid syntax

# %%
For=10
For
# Out:
# 10
