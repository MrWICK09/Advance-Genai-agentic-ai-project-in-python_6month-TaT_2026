# %%
import keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
1var=10
# Out:
#   Cell In[4], line 1
#     1var=10
#     ^
# SyntaxError: invalid decimal literal

# %%
val2@=90
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 val2@=90
#
# NameError: name 'val2' is not defined

# %%
import = 125
# Out:
#   Cell In[6], line 1
#     import = 125
#            ^
# SyntaxError: invalid syntax

# %%
#mULTI LINE COMMENT

""" Aryan
Singh
is
good
boiii
"""
# Out:
# ' Aryan\nSingh\nis\ngood\nboiii\n'

# %%
val2=10

# %%
val_=90

# %%
p=90
q=90
r=q
p
# Out:
# 90

# %%
type(p) , hex(id(p))
# Out:
# (int, '0x950028')

# %%
p=10
p=p+10
p
# Out:
# 20

# %%
a=10
b=2.9876
s= 'Python Language'

print(a)
print(b)
print(s)
# Out:
# 10
# 2.9876
# Python Language

# %%
a , b, c =10,2.9876,'Python Language'
print(a)
print(b)
print(s)
# Out:
# 10
# 2.9876
# Python Language

# %%
str = 'HELLO PYTHON'
print(str)
# Out:
# HELLO PYTHON

# %%
#Defining string with , single ,double and triple quote
str1 = 'HELLO PYTHON:- 1'
str2 = "HELLO PYTHON:- 2"
str3 = '''HELLO PYTHON:- 3'''
str4 = """HELLO PYTHON:- 4"""
print(str1)
print(str2)
print(str3)
print(str4)

type(str1)
type(str2)
type(str3)
# Out:
# HELLO PYTHON:- 1
# HELLO PYTHON:- 2
# HELLO PYTHON:- 3
# HELLO PYTHON:- 4
# str

# %%
#Multi line string 
a=('aryan'
   'is'
   'good')
print(a)
# Out:
# aryanisgood

# %%
add = str1*3
print(add)
# Out:
# HELLO PYTHON:- 1HELLO PYTHON:- 1HELLO PYTHON:- 1

# %%
len(str1)
# Out:
# 16

# %%
#INDEXING

# %%
str1='ARYAN SINGH IS GOOD BOY'

# %%
str1[0]
# Out:
# 'A'

# %%
str1[len(str1)-1]
# Out:
# 'Y'

# %%
str1[-1]
# Out:
# 'Y'

# %%
str1[6]
# Out:
# 'S'

# %%
str1[5]
# Out:
# ' '

# %%
#STRING SLICING

# %%
str1[0:5]
# Out:
# 'ARYAN'

# %%
str1[6:11]
# Out:
# 'SINGH'

# %%
str1[-3:]
# Out:
# 'BOY'

# %%
str1[:4]
# Out:
# 'ARYA'

# %%
str[:5]
# Out:
# 'HELLO'
