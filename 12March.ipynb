# %%
#ONLINE CLASS PRACTICE.

# %%
a=10

# %%
 s3='welcometeam'

# %%
s3[1:5]
# Out:
# 'elco'

# %%
s3[1:8:3]
# Out:
# 'eot'

# %%
s3[::2]
# Out:
# 'wloeem'

# %%
 s3[::-1]
# Out:
# 'maetemoclew'

# %%
s3[::-2]
# Out:
# 'meeolw'

# %%
a=0

# %%
a
# Out:
# 0

# %%
#typecasting

#car() -- #car function without argument
#asian_car('tata','to') -- #car function with 2 argument | type of arguement/parameter string.
#german_cars('audi','bmw','ferrari','vw') #car function with 4 argument | type of arguement string.

# These are the 3 function with 0,2,4 parameter that ends with ():

# %%
#TYPECAST

int(2.3)
# Out:
# 2

# %%
int(2.3,4.3) #it will throw error because we can't pass 2 parameter
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 int(2.3,4.3) #it will throw error because we can't pass 2 parameter
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
float(2) #converting int to float
# Out:
# 2.0

# %%
int(True) # converting boolean to int.
# Out:
# 1

# %%
int(2+9i) # complex number to int number not possible
# Out:
#   Cell In[17], line 1
#     int(2+9i)
#           ^
# SyntaxError: invalid decimal literal

# %%
float(True)
# Out:
# 1.0

# %%
int('10')
# Out:
# 10

# %%
str(10)
# Out:
# '10'

# %%
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
#all other data type to float

float(9)
# Out:
# 9.0

# %%
float(True)
# Out:
# 1.0

# %%
float(3+9i)
# Out:
#   Cell In[25], line 1
#     float(3+9i)
#             ^
# SyntaxError: invalid decimal literal

# %%
float('10')
# Out:
# 10.0

# %%
float('Ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 float('Ten')
#
# ValueError: could not convert string to float: 'Ten'

# %%
#all other data type to bool

# %%
bool(-3) #non zero value gives true
# Out:
# True

# %%
bool(3.5) #non zero value gives true
# Out:
# True

# %%
bool('10') #non zero value gives true
# Out:
# True

# %%
bool("") # zero value gives true
# Out:
# False

# %%
bool(1+2j) #non zero value gives true
# Out:
# True

# %%
bool('seven')
# Out:
# True
