# %%
#TUPLE

# %%
t=()
type(t) #declearing the empty tuple
# Out:
# tuple

# %%
a=(1,2,3,4,5,6)

# %%
type(a)
# Out:
# tuple

# %%
a
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
#Tuple has only 2 function count() and index() function

# %%
a.count(2) #its going to return that how many times the value 2 has been repeated in the tuple.
# Out:
# 1

# %%
a.count(1000) #Usally it should be returning the "error" but it only throw "0" as there is no value present in the tuple "a"
# Out:
# 0

# %%
a.index(3) #going to retun the index of 3 in the tuple.
# Out:
# 2

# %%
#IMPORTANT
a[2]=78 #TUPLE IS NOT MUTABLE
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 #IMPORTANT
# ----> 2 a[2]=78
#
# TypeError: 'tuple' object does not support item assignment

# %%
print(a[0]) #No indexing is allowed.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 print(a[0])
#
# KeyError: 0

# %%
a*3 #its going to multiple the values of tuple into the number of times.
# Out:
# (1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6)

# %%
#SET

# %%
a={}

# %%
type(a) #By default it going to consider it as "dictionary"
# Out:
# dict

# %%
#To declear the set we need to declear it as set()
s1=set() #this is how we declear the set()

# %%
type(s1)
# Out:
# set

# %%
s1={1,2,3,4,5,6}

# %%
s1.add(100)

# %%
s1 # We we use add() function usally it added at the last index but in set it adds according the value. for 100 as its the largest value in the set thats why it add in the last
# Out:
# {1, 2, 3, 4, 5, 6, 100}

# %%
s1.add(0) #For value 0 it will be added in the first.

# %%
s1
# Out:
# {0, 1, 2, 3, 4, 5, 6, 100}

# %%
s2={5,5.5,'nit',1+2j,True}
s2 #Set can contine the different type of the values.
# Out:
# {(1+2j), 5, 5.5, True, 'nit'}

# %%
s2.add(100)
s2 #Over here if we add the value 100 then its going to be added in the random position. because it has different value with different data type.
# Out:
# {(1+2j), 100, 5, 5.5, True, 'nit'}

# %%
s3=s2.copy() #copy one set to another.

# %%
s3
# Out:
# {(1+2j), 100, 5, 5.5, True, 'nit'}

# %%
s3[0]=34
s3 #Indexing and slicing is not allowed in "Set" only allowed in 'List' and 'Dictionary'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 s3[0]=34
#       2 s3
#
# TypeError: 'set' object does not support item assignment

# %%
print(s3[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 print(s3[1])
#
# TypeError: 'set' object is not subscriptable

# %%
print(s3.pop()) #In set pop() function will randomly remove/delete the value from the set. it will not delete the value from the last.
# Out:
# 100

# %%
s3
# Out:
# {(1+2j), 5, 5.5, 'nit'}

# %%
s3.pop(2) #If we pass the index of the value in set it will throw error (indexing not work)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 s3.pop(2)
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
s3.remove(5)
s3 # Remove the element if the element is not available in the set it will throw the error
# Out:
# {(1+2j), 5.5, 'nit'}

# %%
s2.discard(5.5)
s2
# Out:
# {(1+2j), 100, 5, True, 'nit'}

# %%
s2.discard(1000)
s2 #For discard() if the item is available the it will remove but if the values is not available then it won't throw the error.
# Out:
# {(1+2j), 100, 5, True, 'nit'}

# %%
s1
# Out:
# {0, 1, 2, 3, 4, 5, 6, 100}

# %%
s1.add(4)
s1  #Set doesn't allowed the duplicate
# Out:
# {0, 1, 2, 3, 4, 5, 6, 100}
