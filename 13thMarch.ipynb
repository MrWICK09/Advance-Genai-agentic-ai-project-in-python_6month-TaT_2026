# %%
a,b=20,10

# %%
#ARTHIMATIC OPERATOR

# %%
a+b # addition
# Out:
# 30

# %%
a-b #subraction
# Out:
# 10

# %%
a**b #exponental
# Out:
# 10240000000000

# %%
a/b #divide float
# Out:
# 2.0

# %%
a//b #divide int
# Out:
# 2

# %%
a%b #division reminder
# Out:
# 0

# %%
a*b #multiply
# Out:
# 200

# %%
#typecasting complex to any other data type

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(2.4)
# Out:
# (2.4+0j)

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 complex('ten')
#
# ValueError: complex() arg is a malformed string

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex()
# Out:
# 0j

# %%
#ASSIGNMENT OPERATOR

# %%
x=2

# %%
x+=2
x
# Out:
# 6

# %%
x*=2
x
# Out:
# 24

# %%
x/=2
x
# Out:
# 12.0

# %%
x + = 2  #Becasue we provide the space.
x
# Out:
#   Cell In[35], line 1
#     x + = 2
#         ^
# SyntaxError: invalid syntax

# %%
x//=2
x
# Out:
# 6.0

# %%
#UNARY OPERATOR

# %%
n= 7 #negations
n
# Out:
# 7

# %%
m=-n
m
# Out:
# -7

# %%
#In memory we cannot save negative value

# %%
#Relational Operator

# %%
a,b=5,6

# %%
a>b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a>=b
# Out:
# False

# %%
a<=b
# Out:
# True

# %%
#Logical Operator

# %%
a=5
b=4

# %%
a<8 and b<4
# Out:
# False

# %%
a<8 or b<4
# Out:
# True

# %%
a>8 or b<2
# Out:
# False

# %%
x=1
y=2
x,y=y,x
print(x)
print(y)
# Out:
# 2
# 1

# %%
x=1
y=2
x=y;y=x
print(x)
print(y)
# Out:
# 2
# 2

# %%
type(x)=='int'
type(x)
# Out:
# int

# %%
max(45,78,789,2344)
# Out:
# 2344

# %%
true=1
true
# Out:
# 1

# %%
set1={1,4,6,3,8,6}
set1
# Out:
# {1, 3, 4, 6, 8}

# %%
print(type({}))
# Out:
# <class 'dict'>

# %%
str1 = 'str1'
str2 = "str1"
str3 = '''str'''
str4 = 'str1'
print(str1)
print(str2)
print(str3)
print(str4)
# Out:
# str1
# str1
# str
# str1

# %%
type(range(5))
# Out:
# range

# %%
print(10+int("20"))
# Out:
# 30

# %%
x={"a","B"}
print(type(x))
# Out:
# <class 'set'>
